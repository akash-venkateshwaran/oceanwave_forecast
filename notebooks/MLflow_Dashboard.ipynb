# %%
import importlib
from oceanwave_forecast import mlflow_utils, config
importlib.reload(mlflow_utils)
importlib.reload(config)
from mlflow.tracking import MlflowClient
import mlflow
from urllib.parse import quote
from loguru import logger

def fetch_and_log_runs_structured(experiment_name: str):
    """Fetch and display MLflow runs organized by run_number, using PROJ_ROOT/mlruns."""
    # ——— 1. ensure tracking URI is set to PROJ_ROOT/mlruns ———
    mlruns_path = config.PROJ_ROOT / "mlruns"
    mlruns_path.mkdir(parents=True, exist_ok=True)
    # URL‑encode to handle spaces, windows paths, etc.
    uri = f"file:///{quote(str(mlruns_path.absolute()), safe=':/')}"
    mlflow.set_tracking_uri(uri)
    logger.info(f"MLflow tracking URI set to: {uri}")

    try:
        # ——— 2. locate experiment by name ———
        client = MlflowClient()
        exp = client.get_experiment_by_name(experiment_name)
        if exp is None:
            logger.error(f"Experiment '{experiment_name}' not found at {mlruns_path}.")
            return

        # ——— 3. pull runs as DataFrame ———
        runs_df = mlflow.search_runs(
            experiment_ids=[exp.experiment_id],
            order_by=["attributes.start_time DESC"],
            output_format="pandas",
        )
        if runs_df.empty:
            logger.warning(f"No runs found for experiment '{experiment_name}'.")
            return

        # ——— 4. assemble detailed run info ———
        runs_data = []
        for rid in runs_df["run_id"]:
            run = client.get_run(rid)
            runs_data.append({
                "run_id": rid,
                "params": run.data.params,
                "metrics": run.data.metrics,
                "artifacts": [f.path for f in client.list_artifacts(rid)]
            })
        # sort by the integer run_number param
        runs_data.sort(key=lambda x: int(x["params"]["run_number"]))

        # ——— 5. pretty‑print ———
        print("=" * 60)
        print(f"MLFLOW EXPERIMENT: {experiment_name}")
        print("=" * 60)
        for run_data in runs_data:
            params = run_data["params"]
            metrics = run_data["metrics"]
            artifacts = run_data["artifacts"]
            run_number = params["run_number"]
            model_name = params.get("model_type", params.get("model_name", "Unknown"))

            print(f"\n🔹 RUN {run_number} - {model_name}")
            print("-" * 40)
            print("📋 PARAMETERS:")
            for k, v in params.items():
                if k not in {"run_number", "model_type", "model_name"}:
                    print(f"  • {k}: {v}")
            print("📊 METRICS:")
            if metrics:
                for mk, mv in metrics.items():
                    print(f"  • {mk}: {mv:.6f}")
            else:
                print("  • No metrics recorded")
            print("🖼️ ARTIFACTS:")
            if artifacts:
                for artifact in artifacts:
                    print(f"  • {artifact}")
            else:
                print("  • No artifacts recorded")
            print()

    except MlflowException as e:
        logger.exception(f"MLflow error: {e}")
    except Exception as e:
        logger.exception(f"Unexpected error: {e}")

fetch_and_log_runs_structured(config.MLFLOW_CONFIG_BACKTESTING['experiment_name'])
fetch_and_log_runs_structured(config.MLFLOW_DEEPAR_CONFIG['experiment_name'])
# Out:
# 2025-07-28 07:55:13.632 | INFO     | oceanwave_forecast.config:<module>:12 - PROJ_ROOT path is: D:\CML\Term 8\ML projects\forecasting_workspace\oceanwave_forecast
# 2025-07-28 07:55:13.635 | INFO     | oceanwave_forecast.config:<module>:12 - PROJ_ROOT path is: D:\CML\Term 8\ML projects\forecasting_workspace\oceanwave_forecast
# 2025-07-28 07:55:13.637 | INFO     | __main__:fetch_and_log_runs_structured:18 - MLflow tracking URI set to: file:///D:%5CCML%5CTerm%208%5CML%20projects%5Cforecasting_workspace%5Coceanwave_forecast%5Cmlruns
# 2025-07-28 07:55:14.792 | INFO     | __main__:fetch_and_log_runs_structured:18 - MLflow tracking URI set to: file:///D:%5CCML%5CTerm%208%5CML%20projects%5Cforecasting_workspace%5Coceanwave_forecast%5Cmlruns
# ============================================================
# MLFLOW EXPERIMENT: Oceanwave_Backtesting
# ============================================================
#
# 🔹 RUN 0 - NaiveForecaster
# ----------------------------------------
# 📋 PARAMETERS:
#   • forecaster_params: {'forecasters': [('naive_last_WVHT', NaiveForecaster(), [0]), ('naive_mean_APD', NaiveForecaster(strategy='mean'), [1])], 'naive_last_WVHT': NaiveForecaster(), 'naive_mean_APD': NaiveForecaster(strategy='mean'), 'naive_last_WVHT__sp': 1, 'naive_last_WVHT__strategy': 'last', 'naive_last_WVHT__window_length': None, 'naive_mean_APD__sp': 1, 'naive_mean_APD__strategy': 'mean', 'naive_mean_APD__window_length': None}
# 📊 METRICS:
#   • No metrics recorded
# 🖼️ ARTIFACTS:
#   • No artifacts recorded
#
#
# 🔹 RUN 1 - XGBoost
# ----------------------------------------
# 📋 PARAMETERS:
#   • colsample_bytree: 0.8
#   • device: cuda
#   • gamma: 0.0
#   • learning_rate: 0.05
#   • max_depth: 6
#   • min_child_weight: 1.0
#   • n_estimators: 800
#   • n_jobs: -1
#   • objective: reg:squarederror
#   • random_state: 42
#   • reg_alpha: 0.0
#   • reg_lambda: 1.0
#   • subsample: 0.8
#   • targets: WVHT,APD
#   • training_window: 504
#   • tree_method: hist
# 📊 METRICS:
#   • MeanAbsolutePercentageError: 0.253393
#   • MeanSquaredPercentageError: 0.340132
# 🖼️ ARTIFACTS:
#   • plots
#
#
# 🔹 RUN 2 - NaiveForecaster
# ----------------------------------------
# 📋 PARAMETERS:
#   • strategies: {'WVHT': 'last', 'APD': 'mean'}
#   • targets: WVHT,APD
# 📊 METRICS:
#   • MeanAbsolutePercentageError: 0.460528
#   • MeanSquaredPercentageError: 0.623566
# 🖼️ ARTIFACTS:
#   • plots
#
#
# 🔹 RUN 3 - SARIMA
# ----------------------------------------
# 📋 PARAMETERS:
#   • sarima_orders: {'WVHT': {'order': (1, 1, 1), 'seasonal_order': (1, 1, 0, 24)}, 'APD': {'order': (1, 1, 1), 'seasonal_order': (1, 1, 0, 24)}}
#   • targets: WVHT,APD
# 📊 METRICS:
#   • MeanAbsolutePercentageError: 2.309463
#   • MeanSquaredPercentageError: 3.093759
# 🖼️ ARTIFACTS:
#   • plots
#
#
# 🔹 RUN 4 - Naive
# ----------------------------------------
# 📋 PARAMETERS:
#   • forecasters: [('naive_last_WVHT', NaiveForecaster(), ['WVHT']), ('naive_mean_APD', NaiveForecaster(strategy='mean'), ['APD'])]
#   • naive_last_WVHT: NaiveForecaster()
#   • naive_last_WVHT__sp: 1
#   • naive_last_WVHT__strategy: last
#   • naive_last_WVHT__window_length: None
#   • naive_mean_APD: NaiveForecaster(strategy='mean')
#   • naive_mean_APD__sp: 1
#   • naive_mean_APD__strategy: mean
#   • naive_mean_APD__window_length: None
#   • strategies: {'WVHT': 'last', 'APD': 'mean'}
#   • targets: WVHT,APD
# 📊 METRICS:
#   • MeanAbsolutePercentageError: 0.673963
#   • MeanSquaredPercentageError: 0.904097
# 🖼️ ARTIFACTS:
#   • plots
#
#
# 🔹 RUN 5 - Naive
# ----------------------------------------
# 📋 PARAMETERS:
#   • forecasters: [('naive_last_WVHT', NaiveForecaster(), ['WVHT']), ('naive_mean_APD', NaiveForecaster(strategy='mean'), ['APD'])]
#   • naive_last_WVHT: NaiveForecaster()
#   • naive_last_WVHT__sp: 1
#   • naive_last_WVHT__strategy: last
#   • naive_last_WVHT__window_length: None
#   • naive_mean_APD: NaiveForecaster(strategy='mean')
#   • naive_mean_APD__sp: 1
#   • naive_mean_APD__strategy: mean
#   • naive_mean_APD__window_length: None
#   • strategies: {'WVHT': 'last', 'APD': 'mean'}
#   • targets: WVHT,APD
# 📊 METRICS:
#   • MeanAbsolutePercentageError: 0.673963
#   • MeanSquaredPercentageError: 0.904097
# 🖼️ ARTIFACTS:
#   • plots
#
#
# 🔹 RUN 6 - XGBoost
# ----------------------------------------
# 📋 PARAMETERS:
#   • colsample_bytree: 0.8
#   • device: cuda
#   • estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device='cuda', early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=0.0, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=1.0, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=800,
#              n_jobs=-1, num_parallel_tree=None, ...)
#   • estimator__base_score: None
#   • estimator__booster: None
#   • estimator__callbacks: None
#   • estimator__colsample_bylevel: None
#   • estimator__colsample_bynode: None
#   • estimator__colsample_bytree: 0.8
#   • estimator__device: cuda
#   • estimator__early_stopping_rounds: None
#   • estimator__enable_categorical: False
#   • estimator__eval_metric: None
#   • estimator__feature_types: None
#   • estimator__feature_weights: None
#   • estimator__gamma: 0.0
#   • estimator__grow_policy: None
#   • estimator__importance_type: None
#   • estimator__interaction_constraints: None
#   • estimator__learning_rate: 0.05
#   • estimator__max_bin: None
#   • estimator__max_cat_threshold: None
#   • estimator__max_cat_to_onehot: None
#   • estimator__max_delta_step: None
#   • estimator__max_depth: 6
#   • estimator__max_leaves: None
#   • estimator__min_child_weight: 1.0
#   • estimator__missing: nan
#   • estimator__monotone_constraints: None
#   • estimator__multi_strategy: None
#   • estimator__num_parallel_tree: None
#   • estimator__n_estimators: 800
#   • estimator__n_jobs: -1
#   • estimator__objective: reg:squarederror
#   • estimator__random_state: 42
#   • estimator__reg_alpha: 0.0
#   • estimator__reg_lambda: 1.0
#   • estimator__sampling_method: None
#   • estimator__scale_pos_weight: None
#   • estimator__subsample: 0.8
#   • estimator__tree_method: hist
#   • estimator__validate_parameters: None
#   • estimator__verbosity: None
#   • gamma: 0.0
#   • learning_rate: 0.05
#   • max_depth: 6
#   • min_child_weight: 1.0
#   • n_estimators: 800
#   • n_jobs: -1
#   • objective: reg:squarederror
#   • pooling: local
#   • random_state: 42
#   • reg_alpha: 0.0
#   • reg_lambda: 1.0
#   • subsample: 0.8
#   • targets: WVHT,APD
#   • training_window: 504
#   • transformers: None
#   • tree_method: hist
#   • window_length: 504
# 📊 METRICS:
#   • No metrics recorded
# 🖼️ ARTIFACTS:
#   • No artifacts recorded
#
#
# 🔹 RUN 7 - XGBoost
# ----------------------------------------
# 📋 PARAMETERS:
#   • colsample_bytree: 0.8
#   • device: cuda
#   • estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device='cuda', early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=0.0, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=1.0, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=800,
#              n_jobs=-1, num_parallel_tree=None, ...)
#   • estimator__base_score: None
#   • estimator__booster: None
#   • estimator__callbacks: None
#   • estimator__colsample_bylevel: None
#   • estimator__colsample_bynode: None
#   • estimator__colsample_bytree: 0.8
#   • estimator__device: cuda
#   • estimator__early_stopping_rounds: None
#   • estimator__enable_categorical: False
#   • estimator__eval_metric: None
#   • estimator__feature_types: None
#   • estimator__feature_weights: None
#   • estimator__gamma: 0.0
#   • estimator__grow_policy: None
#   • estimator__importance_type: None
#   • estimator__interaction_constraints: None
#   • estimator__learning_rate: 0.05
#   • estimator__max_bin: None
#   • estimator__max_cat_threshold: None
#   • estimator__max_cat_to_onehot: None
#   • estimator__max_delta_step: None
#   • estimator__max_depth: 6
#   • estimator__max_leaves: None
#   • estimator__min_child_weight: 1.0
#   • estimator__missing: nan
#   • estimator__monotone_constraints: None
#   • estimator__multi_strategy: None
#   • estimator__num_parallel_tree: None
#   • estimator__n_estimators: 800
#   • estimator__n_jobs: -1
#   • estimator__objective: reg:squarederror
#   • estimator__random_state: 42
#   • estimator__reg_alpha: 0.0
#   • estimator__reg_lambda: 1.0
#   • estimator__sampling_method: None
#   • estimator__scale_pos_weight: None
#   • estimator__subsample: 0.8
#   • estimator__tree_method: hist
#   • estimator__validate_parameters: None
#   • estimator__verbosity: None
#   • gamma: 0.0
#   • learning_rate: 0.05
#   • max_depth: 6
#   • min_child_weight: 1.0
#   • n_estimators: 800
#   • n_jobs: -1
#   • objective: reg:squarederror
#   • pooling: local
#   • random_state: 42
#   • reg_alpha: 0.0
#   • reg_lambda: 1.0
#   • subsample: 0.8
#   • targets: WVHT,APD
#   • transformers: [WindowSummarizer(lag_feature={'lag': [1, 24, 48, 72]}, truncate='bfill')]
#   • tree_method: hist
#   • window_length: 504
# 📊 METRICS:
#   • No metrics recorded
# 🖼️ ARTIFACTS:
#   • No artifacts recorded
#
#
# 🔹 RUN 8 - Naive
# ----------------------------------------
# 📋 PARAMETERS:
#   • forecasters: [('naive_last_WVHT', NaiveForecaster(), ['WVHT']), ('naive_mean_APD', NaiveForecaster(strategy='mean'), ['APD'])]
#   • naive_last_WVHT: NaiveForecaster()
#   • naive_last_WVHT__sp: 1
#   • naive_last_WVHT__strategy: last
#   • naive_last_WVHT__window_length: None
#   • naive_mean_APD: NaiveForecaster(strategy='mean')
#   • naive_mean_APD__sp: 1
#   • naive_mean_APD__strategy: mean
#   • naive_mean_APD__window_length: None
#   • strategies: {'WVHT': 'last', 'APD': 'mean'}
#   • targets: WVHT,APD
# 📊 METRICS:
#   • MeanAbsolutePercentageError: 0.673963
#   • MeanSquaredPercentageError: 0.904097
# 🖼️ ARTIFACTS:
#   • plots
#
#
# 🔹 RUN 9 - SARIMA
# ----------------------------------------
# 📋 PARAMETERS:
#   • forecasters: [('SARIMA_WVHT', ARIMA(order=(1, 0, 1), seasonal_order=(0, 0, 0, 24)), ['WVHT']), ('SARIMA_APD', ARIMA(order=(1, 0, 1), seasonal_order=(0, 0, 0, 24)), ['APD'])]
#   • SARIMA_APD: ARIMA(order=(1, 0, 1), seasonal_order=(0, 0, 0, 24))
#   • SARIMA_APD__concentrate_scale: False
#   • SARIMA_APD__enforce_invertibility: True
#   • SARIMA_APD__enforce_stationarity: True
#   • SARIMA_APD__hamilton_representation: False
#   • SARIMA_APD__maxiter: 50
#   • SARIMA_APD__measurement_error: False
#   • SARIMA_APD__method: lbfgs
#   • SARIMA_APD__mle_regression: True
#   • SARIMA_APD__order: (1, 0, 1)
#   • SARIMA_APD__out_of_sample_size: 0
#   • SARIMA_APD__scoring: mse
#   • SARIMA_APD__scoring_args: None
#   • SARIMA_APD__seasonal_order: (0, 0, 0, 24)
#   • SARIMA_APD__simple_differencing: False
#   • SARIMA_APD__start_params: None
#   • SARIMA_APD__suppress_warnings: False
#   • SARIMA_APD__time_varying_regression: False
#   • SARIMA_APD__trend: None
#   • SARIMA_APD__with_intercept: True
#   • sarima_orders: {'WVHT': {'order': (1, 0, 1), 'seasonal_order': (0, 0, 0, 24)}, 'APD': {'order': (1, 0, 1), 'seasonal_order': (0, 0, 0, 24)}}
#   • SARIMA_WVHT: ARIMA(order=(1, 0, 1), seasonal_order=(0, 0, 0, 24))
#   • SARIMA_WVHT__concentrate_scale: False
#   • SARIMA_WVHT__enforce_invertibility: True
#   • SARIMA_WVHT__enforce_stationarity: True
#   • SARIMA_WVHT__hamilton_representation: False
#   • SARIMA_WVHT__maxiter: 50
#   • SARIMA_WVHT__measurement_error: False
#   • SARIMA_WVHT__method: lbfgs
#   • SARIMA_WVHT__mle_regression: True
#   • SARIMA_WVHT__order: (1, 0, 1)
#   • SARIMA_WVHT__out_of_sample_size: 0
#   • SARIMA_WVHT__scoring: mse
#   • SARIMA_WVHT__scoring_args: None
#   • SARIMA_WVHT__seasonal_order: (0, 0, 0, 24)
#   • SARIMA_WVHT__simple_differencing: False
#   • SARIMA_WVHT__start_params: None
#   • SARIMA_WVHT__suppress_warnings: False
#   • SARIMA_WVHT__time_varying_regression: False
#   • SARIMA_WVHT__trend: None
#   • SARIMA_WVHT__with_intercept: True
#   • targets: WVHT,APD
# 📊 METRICS:
#   • MeanAbsolutePercentageError: 0.551020
#   • MeanSquaredPercentageError: 0.792764
# 🖼️ ARTIFACTS:
#   • plots
#
#
# 🔹 RUN 10 - XGBoost
# ----------------------------------------
# 📋 PARAMETERS:
#   • colsample_bytree: 0.8
#   • device: cuda
#   • estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device='cuda', early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=0.0, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=1.0, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=800,
#              n_jobs=-1, num_parallel_tree=None, ...)
#   • estimator__base_score: None
#   • estimator__booster: None
#   • estimator__callbacks: None
#   • estimator__colsample_bylevel: None
#   • estimator__colsample_bynode: None
#   • estimator__colsample_bytree: 0.8
#   • estimator__device: cuda
#   • estimator__early_stopping_rounds: None
#   • estimator__enable_categorical: False
#   • estimator__eval_metric: None
#   • estimator__feature_types: None
#   • estimator__feature_weights: None
#   • estimator__gamma: 0.0
#   • estimator__grow_policy: None
#   • estimator__importance_type: None
#   • estimator__interaction_constraints: None
#   • estimator__learning_rate: 0.05
#   • estimator__max_bin: None
#   • estimator__max_cat_threshold: None
#   • estimator__max_cat_to_onehot: None
#   • estimator__max_delta_step: None
#   • estimator__max_depth: 6
#   • estimator__max_leaves: None
#   • estimator__min_child_weight: 1.0
#   • estimator__missing: nan
#   • estimator__monotone_constraints: None
#   • estimator__multi_strategy: None
#   • estimator__num_parallel_tree: None
#   • estimator__n_estimators: 800
#   • estimator__n_jobs: -1
#   • estimator__objective: reg:squarederror
#   • estimator__random_state: 42
#   • estimator__reg_alpha: 0.0
#   • estimator__reg_lambda: 1.0
#   • estimator__sampling_method: None
#   • estimator__scale_pos_weight: None
#   • estimator__subsample: 0.8
#   • estimator__tree_method: hist
#   • estimator__validate_parameters: None
#   • estimator__verbosity: None
#   • gamma: 0.0
#   • learning_rate: 0.05
#   • max_depth: 6
#   • min_child_weight: 1.0
#   • n_estimators: 800
#   • n_jobs: -1
#   • objective: reg:squarederror
#   • pooling: local
#   • random_state: 42
#   • reg_alpha: 0.0
#   • reg_lambda: 1.0
#   • subsample: 0.8
#   • targets: WVHT,APD
#   • transformers: [WindowSummarizer(lag_feature={'lag': [1, 24, 48, 72]}, truncate='bfill')]
#   • tree_method: hist
#   • window_length: 10
# 📊 METRICS:
#   • No metrics recorded
# 🖼️ ARTIFACTS:
#   • No artifacts recorded
#
#
# 🔹 RUN 11 - XGBoost
# ----------------------------------------
# 📋 PARAMETERS:
#   • colsample_bytree: 0.8
#   • device: cuda
#   • estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device='cuda', early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=0.0, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=1.0, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=800,
#              n_jobs=-1, num_parallel_tree=None, ...)
#   • estimator__base_score: None
#   • estimator__booster: None
#   • estimator__callbacks: None
#   • estimator__colsample_bylevel: None
#   • estimator__colsample_bynode: None
#   • estimator__colsample_bytree: 0.8
#   • estimator__device: cuda
#   • estimator__early_stopping_rounds: None
#   • estimator__enable_categorical: False
#   • estimator__eval_metric: None
#   • estimator__feature_types: None
#   • estimator__feature_weights: None
#   • estimator__gamma: 0.0
#   • estimator__grow_policy: None
#   • estimator__importance_type: None
#   • estimator__interaction_constraints: None
#   • estimator__learning_rate: 0.05
#   • estimator__max_bin: None
#   • estimator__max_cat_threshold: None
#   • estimator__max_cat_to_onehot: None
#   • estimator__max_delta_step: None
#   • estimator__max_depth: 6
#   • estimator__max_leaves: None
#   • estimator__min_child_weight: 1.0
#   • estimator__missing: nan
#   • estimator__monotone_constraints: None
#   • estimator__multi_strategy: None
#   • estimator__num_parallel_tree: None
#   • estimator__n_estimators: 800
#   • estimator__n_jobs: -1
#   • estimator__objective: reg:squarederror
#   • estimator__random_state: 42
#   • estimator__reg_alpha: 0.0
#   • estimator__reg_lambda: 1.0
#   • estimator__sampling_method: None
#   • estimator__scale_pos_weight: None
#   • estimator__subsample: 0.8
#   • estimator__tree_method: hist
#   • estimator__validate_parameters: None
#   • estimator__verbosity: None
#   • gamma: 0.0
#   • learning_rate: 0.05
#   • max_depth: 6
#   • min_child_weight: 1.0
#   • n_estimators: 800
#   • n_jobs: -1
#   • objective: reg:squarederror
#   • pooling: local
#   • random_state: 42
#   • reg_alpha: 0.0
#   • reg_lambda: 1.0
#   • subsample: 0.8
#   • targets: WVHT,APD
#   • transformers: [WindowSummarizer(lag_feature={'lag': [1, 24, 48, 72]}, truncate='bfill')]
#   • tree_method: hist
#   • window_length: None
# 📊 METRICS:
#   • No metrics recorded
# 🖼️ ARTIFACTS:
#   • No artifacts recorded
#
#
# 🔹 RUN 12 - XGBoost
# ----------------------------------------
# 📋 PARAMETERS:
#   • colsample_bytree: 0.8
#   • device: cuda
#   • estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device='cuda', early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=0.0, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=1.0, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=800,
#              n_jobs=-1, num_parallel_tree=None, ...)
#   • estimator__base_score: None
#   • estimator__booster: None
#   • estimator__callbacks: None
#   • estimator__colsample_bylevel: None
#   • estimator__colsample_bynode: None
#   • estimator__colsample_bytree: 0.8
#   • estimator__device: cuda
#   • estimator__early_stopping_rounds: None
#   • estimator__enable_categorical: False
#   • estimator__eval_metric: None
#   • estimator__feature_types: None
#   • estimator__feature_weights: None
#   • estimator__gamma: 0.0
#   • estimator__grow_policy: None
#   • estimator__importance_type: None
#   • estimator__interaction_constraints: None
#   • estimator__learning_rate: 0.05
#   • estimator__max_bin: None
#   • estimator__max_cat_threshold: None
#   • estimator__max_cat_to_onehot: None
#   • estimator__max_delta_step: None
#   • estimator__max_depth: 6
#   • estimator__max_leaves: None
#   • estimator__min_child_weight: 1.0
#   • estimator__missing: nan
#   • estimator__monotone_constraints: None
#   • estimator__multi_strategy: None
#   • estimator__num_parallel_tree: None
#   • estimator__n_estimators: 800
#   • estimator__n_jobs: -1
#   • estimator__objective: reg:squarederror
#   • estimator__random_state: 42
#   • estimator__reg_alpha: 0.0
#   • estimator__reg_lambda: 1.0
#   • estimator__sampling_method: None
#   • estimator__scale_pos_weight: None
#   • estimator__subsample: 0.8
#   • estimator__tree_method: hist
#   • estimator__validate_parameters: None
#   • estimator__verbosity: None
#   • gamma: 0.0
#   • learning_rate: 0.05
#   • max_depth: 6
#   • min_child_weight: 1.0
#   • n_estimators: 800
#   • n_jobs: -1
#   • objective: reg:squarederror
#   • pooling: global
#   • random_state: 42
#   • reg_alpha: 0.0
#   • reg_lambda: 1.0
#   • subsample: 0.8
#   • targets: WVHT,APD
#   • transformers: [WindowSummarizer(lag_feature={'lag': [1, 24, 48, 72]}, truncate='bfill')]
#   • tree_method: hist
#   • window_length: None
# 📊 METRICS:
#   • MeanAbsolutePercentageError: 0.921900
#   • MeanSquaredPercentageError: 1.256706
# 🖼️ ARTIFACTS:
#   • plots
#
#
# 🔹 RUN 13 - XGBoost
# ----------------------------------------
# 📋 PARAMETERS:
#   • colsample_bytree: 0.8
#   • device: cuda
#   • estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device='cuda', early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=0.0, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=1.0, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=800,
#              n_jobs=-1, num_parallel_tree=None, ...)
#   • estimator__base_score: None
#   • estimator__booster: None
#   • estimator__callbacks: None
#   • estimator__colsample_bylevel: None
#   • estimator__colsample_bynode: None
#   • estimator__colsample_bytree: 0.8
#   • estimator__device: cuda
#   • estimator__early_stopping_rounds: None
#   • estimator__enable_categorical: False
#   • estimator__eval_metric: None
#   • estimator__feature_types: None
#   • estimator__feature_weights: None
#   • estimator__gamma: 0.0
#   • estimator__grow_policy: None
#   • estimator__importance_type: None
#   • estimator__interaction_constraints: None
#   • estimator__learning_rate: 0.05
#   • estimator__max_bin: None
#   • estimator__max_cat_threshold: None
#   • estimator__max_cat_to_onehot: None
#   • estimator__max_delta_step: None
#   • estimator__max_depth: 6
#   • estimator__max_leaves: None
#   • estimator__min_child_weight: 1.0
#   • estimator__missing: nan
#   • estimator__monotone_constraints: None
#   • estimator__multi_strategy: None
#   • estimator__num_parallel_tree: None
#   • estimator__n_estimators: 800
#   • estimator__n_jobs: -1
#   • estimator__objective: reg:squarederror
#   • estimator__random_state: 42
#   • estimator__reg_alpha: 0.0
#   • estimator__reg_lambda: 1.0
#   • estimator__sampling_method: None
#   • estimator__scale_pos_weight: None
#   • estimator__subsample: 0.8
#   • estimator__tree_method: hist
#   • estimator__validate_parameters: None
#   • estimator__verbosity: None
#   • gamma: 0.0
#   • learning_rate: 0.05
#   • max_depth: 6
#   • min_child_weight: 1.0
#   • n_estimators: 800
#   • n_jobs: -1
#   • objective: reg:squarederror
#   • pooling: global
#   • random_state: 42
#   • reg_alpha: 0.0
#   • reg_lambda: 1.0
#   • subsample: 0.8
#   • targets: WVHT,APD
#   • transformers: [WindowSummarizer(lag_feature={'lag': [1, 24, 48, 72]}, truncate='bfill')]
#   • tree_method: hist
#   • window_length: None
# 📊 METRICS:
#   • MeanAbsolutePercentageError: 0.921900
#   • MeanSquaredPercentageError: 1.256706
# 🖼️ ARTIFACTS:
#   • plots
#
#
# 🔹 RUN 14 - XGBoost
# ----------------------------------------
# 📋 PARAMETERS:
#   • colsample_bytree: 0.8
#   • device: cuda
#   • estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device='cuda', early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=0.0, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=1.0, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=800,
#              n_jobs=-1, num_parallel_tree=None, ...)
#   • estimator__base_score: None
#   • estimator__booster: None
#   • estimator__callbacks: None
#   • estimator__colsample_bylevel: None
#   • estimator__colsample_bynode: None
#   • estimator__colsample_bytree: 0.8
#   • estimator__device: cuda
#   • estimator__early_stopping_rounds: None
#   • estimator__enable_categorical: False
#   • estimator__eval_metric: None
#   • estimator__feature_types: None
#   • estimator__feature_weights: None
#   • estimator__gamma: 0.0
#   • estimator__grow_policy: None
#   • estimator__importance_type: None
#   • estimator__interaction_constraints: None
#   • estimator__learning_rate: 0.05
#   • estimator__max_bin: None
#   • estimator__max_cat_threshold: None
#   • estimator__max_cat_to_onehot: None
#   • estimator__max_delta_step: None
#   • estimator__max_depth: 6
#   • estimator__max_leaves: None
#   • estimator__min_child_weight: 1.0
#   • estimator__missing: nan
#   • estimator__monotone_constraints: None
#   • estimator__multi_strategy: None
#   • estimator__num_parallel_tree: None
#   • estimator__n_estimators: 800
#   • estimator__n_jobs: -1
#   • estimator__objective: reg:squarederror
#   • estimator__random_state: 42
#   • estimator__reg_alpha: 0.0
#   • estimator__reg_lambda: 1.0
#   • estimator__sampling_method: None
#   • estimator__scale_pos_weight: None
#   • estimator__subsample: 0.8
#   • estimator__tree_method: hist
#   • estimator__validate_parameters: None
#   • estimator__verbosity: None
#   • gamma: 0.0
#   • learning_rate: 0.05
#   • max_depth: 6
#   • min_child_weight: 1.0
#   • n_estimators: 800
#   • n_jobs: -1
#   • objective: reg:squarederror
#   • pooling: global
#   • random_state: 42
#   • reg_alpha: 0.0
#   • reg_lambda: 1.0
#   • subsample: 0.8
#   • targets: WVHT,APD
#   • transformers: [WindowSummarizer(lag_feature={'lag': [1, 24, 48, 72]}, truncate='bfill')]
#   • tree_method: hist
#   • window_length: None
# 📊 METRICS:
#   • MeanAbsolutePercentageError: 0.921900
#   • MeanSquaredPercentageError: 1.256706
# 🖼️ ARTIFACTS:
#   • plots
#
#
# 🔹 RUN 15 - Naive
# ----------------------------------------
# 📋 PARAMETERS:
#   • forecasters: [('naive_last_WVHT', NaiveForecaster(), ['WVHT']), ('naive_mean_APD', NaiveForecaster(strategy='mean'), ['APD'])]
#   • naive_last_WVHT: NaiveForecaster()
#   • naive_last_WVHT__sp: 1
#   • naive_last_WVHT__strategy: last
#   • naive_last_WVHT__window_length: None
#   • naive_mean_APD: NaiveForecaster(strategy='mean')
#   • naive_mean_APD__sp: 1
#   • naive_mean_APD__strategy: mean
#   • naive_mean_APD__window_length: None
#   • strategies: {'WVHT': 'last', 'APD': 'mean'}
#   • targets: WVHT,APD
# 📊 METRICS:
#   • MeanAbsolutePercentageError: 0.673963
#   • MeanSquaredPercentageError: 0.904097
# 🖼️ ARTIFACTS:
#   • plots
#
#
# 🔹 RUN 16 - SARIMA
# ----------------------------------------
# 📋 PARAMETERS:
#   • forecasters: [('SARIMA_WVHT', ARIMA(order=(1, 0, 1), seasonal_order=(0, 0, 0, 24)), ['WVHT']), ('SARIMA_APD', ARIMA(order=(1, 0, 1), seasonal_order=(0, 0, 0, 24)), ['APD'])]
#   • SARIMA_APD: ARIMA(order=(1, 0, 1), seasonal_order=(0, 0, 0, 24))
#   • SARIMA_APD__concentrate_scale: False
#   • SARIMA_APD__enforce_invertibility: True
#   • SARIMA_APD__enforce_stationarity: True
#   • SARIMA_APD__hamilton_representation: False
#   • SARIMA_APD__maxiter: 50
#   • SARIMA_APD__measurement_error: False
#   • SARIMA_APD__method: lbfgs
#   • SARIMA_APD__mle_regression: True
#   • SARIMA_APD__order: (1, 0, 1)
#   • SARIMA_APD__out_of_sample_size: 0
#   • SARIMA_APD__scoring: mse
#   • SARIMA_APD__scoring_args: None
#   • SARIMA_APD__seasonal_order: (0, 0, 0, 24)
#   • SARIMA_APD__simple_differencing: False
#   • SARIMA_APD__start_params: None
#   • SARIMA_APD__suppress_warnings: False
#   • SARIMA_APD__time_varying_regression: False
#   • SARIMA_APD__trend: None
#   • SARIMA_APD__with_intercept: True
#   • sarima_orders: {'WVHT': {'order': (1, 0, 1), 'seasonal_order': (0, 0, 0, 24)}, 'APD': {'order': (1, 0, 1), 'seasonal_order': (0, 0, 0, 24)}}
#   • SARIMA_WVHT: ARIMA(order=(1, 0, 1), seasonal_order=(0, 0, 0, 24))
#   • SARIMA_WVHT__concentrate_scale: False
#   • SARIMA_WVHT__enforce_invertibility: True
#   • SARIMA_WVHT__enforce_stationarity: True
#   • SARIMA_WVHT__hamilton_representation: False
#   • SARIMA_WVHT__maxiter: 50
#   • SARIMA_WVHT__measurement_error: False
#   • SARIMA_WVHT__method: lbfgs
#   • SARIMA_WVHT__mle_regression: True
#   • SARIMA_WVHT__order: (1, 0, 1)
#   • SARIMA_WVHT__out_of_sample_size: 0
#   • SARIMA_WVHT__scoring: mse
#   • SARIMA_WVHT__scoring_args: None
#   • SARIMA_WVHT__seasonal_order: (0, 0, 0, 24)
#   • SARIMA_WVHT__simple_differencing: False
#   • SARIMA_WVHT__start_params: None
#   • SARIMA_WVHT__suppress_warnings: False
#   • SARIMA_WVHT__time_varying_regression: False
#   • SARIMA_WVHT__trend: None
#   • SARIMA_WVHT__with_intercept: True
#   • targets: WVHT,APD
# 📊 METRICS:
#   • MeanAbsolutePercentageError: 0.551020
#   • MeanSquaredPercentageError: 0.792764
# 🖼️ ARTIFACTS:
#   • plots
#
#
# 🔹 RUN 17 - XGBoost
# ----------------------------------------
# 📋 PARAMETERS:
#   • colsample_bytree: 0.8
#   • device: cuda
#   • estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device='cuda', early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=0.0, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=1.0, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=2000,
#              n_jobs=-1, num_parallel_tree=None, ...)
#   • estimator__base_score: None
#   • estimator__booster: None
#   • estimator__callbacks: None
#   • estimator__colsample_bylevel: None
#   • estimator__colsample_bynode: None
#   • estimator__colsample_bytree: 0.8
#   • estimator__device: cuda
#   • estimator__early_stopping_rounds: None
#   • estimator__enable_categorical: False
#   • estimator__eval_metric: None
#   • estimator__feature_types: None
#   • estimator__feature_weights: None
#   • estimator__gamma: 0.0
#   • estimator__grow_policy: None
#   • estimator__importance_type: None
#   • estimator__interaction_constraints: None
#   • estimator__learning_rate: 0.05
#   • estimator__max_bin: None
#   • estimator__max_cat_threshold: None
#   • estimator__max_cat_to_onehot: None
#   • estimator__max_delta_step: None
#   • estimator__max_depth: 6
#   • estimator__max_leaves: None
#   • estimator__min_child_weight: 1.0
#   • estimator__missing: nan
#   • estimator__monotone_constraints: None
#   • estimator__multi_strategy: None
#   • estimator__num_parallel_tree: None
#   • estimator__n_estimators: 2000
#   • estimator__n_jobs: -1
#   • estimator__objective: reg:squarederror
#   • estimator__random_state: 42
#   • estimator__reg_alpha: 0.0
#   • estimator__reg_lambda: 1.0
#   • estimator__sampling_method: None
#   • estimator__scale_pos_weight: None
#   • estimator__subsample: 0.8
#   • estimator__tree_method: hist
#   • estimator__validate_parameters: None
#   • estimator__verbosity: None
#   • gamma: 0.0
#   • learning_rate: 0.05
#   • max_depth: 6
#   • min_child_weight: 1.0
#   • n_estimators: 2000
#   • n_jobs: -1
#   • objective: reg:squarederror
#   • pooling: global
#   • random_state: 42
#   • reg_alpha: 0.0
#   • reg_lambda: 1.0
#   • subsample: 0.8
#   • targets: WVHT,APD
#   • transformers: [WindowSummarizer(lag_feature={'lag': [1, 24, 48, 72]}, truncate='bfill')]
#   • tree_method: hist
#   • window_length: None
# 📊 METRICS:
#   • MeanAbsolutePercentageError: 0.929118
#   • MeanSquaredPercentageError: 1.286189
# 🖼️ ARTIFACTS:
#   • plots
#
#
# 🔹 RUN 18 - XGBoost
# ----------------------------------------
# 📋 PARAMETERS:
#   • colsample_bytree: 0.8
#   • device: cuda
#   • estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device='cuda', early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=0.0, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=1.0, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=2000,
#              n_jobs=-1, num_parallel_tree=None, ...)
#   • estimator__base_score: None
#   • estimator__booster: None
#   • estimator__callbacks: None
#   • estimator__colsample_bylevel: None
#   • estimator__colsample_bynode: None
#   • estimator__colsample_bytree: 0.8
#   • estimator__device: cuda
#   • estimator__early_stopping_rounds: None
#   • estimator__enable_categorical: False
#   • estimator__eval_metric: None
#   • estimator__feature_types: None
#   • estimator__feature_weights: None
#   • estimator__gamma: 0.0
#   • estimator__grow_policy: None
#   • estimator__importance_type: None
#   • estimator__interaction_constraints: None
#   • estimator__learning_rate: 0.05
#   • estimator__max_bin: None
#   • estimator__max_cat_threshold: None
#   • estimator__max_cat_to_onehot: None
#   • estimator__max_delta_step: None
#   • estimator__max_depth: 6
#   • estimator__max_leaves: None
#   • estimator__min_child_weight: 1.0
#   • estimator__missing: nan
#   • estimator__monotone_constraints: None
#   • estimator__multi_strategy: None
#   • estimator__num_parallel_tree: None
#   • estimator__n_estimators: 2000
#   • estimator__n_jobs: -1
#   • estimator__objective: reg:squarederror
#   • estimator__random_state: 42
#   • estimator__reg_alpha: 0.0
#   • estimator__reg_lambda: 1.0
#   • estimator__sampling_method: None
#   • estimator__scale_pos_weight: None
#   • estimator__subsample: 0.8
#   • estimator__tree_method: hist
#   • estimator__validate_parameters: None
#   • estimator__verbosity: None
#   • gamma: 0.0
#   • learning_rate: 0.05
#   • max_depth: 6
#   • min_child_weight: 1.0
#   • n_estimators: 2000
#   • n_jobs: -1
#   • objective: reg:squarederror
#   • pooling: global
#   • random_state: 42
#   • reg_alpha: 0.0
#   • reg_lambda: 1.0
#   • subsample: 0.8
#   • targets: WVHT,APD
#   • transformers: [WindowSummarizer(lag_feature={'lag': [1, 24, 48, 72]}, truncate='bfill')]
#   • tree_method: hist
#   • window_length: None
# 📊 METRICS:
#   • MeanAbsolutePercentageError: 0.647021
#   • MeanSquaredPercentageError: 0.810431
# 🖼️ ARTIFACTS:
#   • plots
#
#
# 🔹 RUN 19 - SARIMA
# ----------------------------------------
# 📋 PARAMETERS:
#   • forecasters: [('SARIMA_WVHT', ARIMA(order=(1, 0, 1), seasonal_order=(0, 0, 0, 24)), ['WVHT']), ('SARIMA_APD', ARIMA(order=(1, 0, 1), seasonal_order=(0, 0, 0, 24)), ['APD'])]
#   • SARIMA_APD: ARIMA(order=(1, 0, 1), seasonal_order=(0, 0, 0, 24))
#   • SARIMA_APD__concentrate_scale: False
#   • SARIMA_APD__enforce_invertibility: True
#   • SARIMA_APD__enforce_stationarity: True
#   • SARIMA_APD__hamilton_representation: False
#   • SARIMA_APD__maxiter: 50
#   • SARIMA_APD__measurement_error: False
#   • SARIMA_APD__method: lbfgs
#   • SARIMA_APD__mle_regression: True
#   • SARIMA_APD__order: (1, 0, 1)
#   • SARIMA_APD__out_of_sample_size: 0
#   • SARIMA_APD__scoring: mse
#   • SARIMA_APD__scoring_args: None
#   • SARIMA_APD__seasonal_order: (0, 0, 0, 24)
#   • SARIMA_APD__simple_differencing: False
#   • SARIMA_APD__start_params: None
#   • SARIMA_APD__suppress_warnings: False
#   • SARIMA_APD__time_varying_regression: False
#   • SARIMA_APD__trend: None
#   • SARIMA_APD__with_intercept: True
#   • sarima_orders: {'WVHT': {'order': (1, 0, 1), 'seasonal_order': (0, 0, 0, 24)}, 'APD': {'order': (1, 0, 1), 'seasonal_order': (0, 0, 0, 24)}}
#   • SARIMA_WVHT: ARIMA(order=(1, 0, 1), seasonal_order=(0, 0, 0, 24))
#   • SARIMA_WVHT__concentrate_scale: False
#   • SARIMA_WVHT__enforce_invertibility: True
#   • SARIMA_WVHT__enforce_stationarity: True
#   • SARIMA_WVHT__hamilton_representation: False
#   • SARIMA_WVHT__maxiter: 50
#   • SARIMA_WVHT__measurement_error: False
#   • SARIMA_WVHT__method: lbfgs
#   • SARIMA_WVHT__mle_regression: True
#   • SARIMA_WVHT__order: (1, 0, 1)
#   • SARIMA_WVHT__out_of_sample_size: 0
#   • SARIMA_WVHT__scoring: mse
#   • SARIMA_WVHT__scoring_args: None
#   • SARIMA_WVHT__seasonal_order: (0, 0, 0, 24)
#   • SARIMA_WVHT__simple_differencing: False
#   • SARIMA_WVHT__start_params: None
#   • SARIMA_WVHT__suppress_warnings: False
#   • SARIMA_WVHT__time_varying_regression: False
#   • SARIMA_WVHT__trend: None
#   • SARIMA_WVHT__with_intercept: True
#   • targets: WVHT,APD
# 📊 METRICS:
#   • MeanAbsolutePercentageError: 0.479542
#   • MeanSquaredPercentageError: 0.651016
# 🖼️ ARTIFACTS:
#   • plots
#
#
# 🔹 RUN 20 - XGBoost
# ----------------------------------------
# 📋 PARAMETERS:
#   • colsample_bytree: 0.8
#   • device: cuda
#   • estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device='cuda', early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=0.0, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=1.0, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=2000,
#              n_jobs=-1, num_parallel_tree=None, ...)
#   • estimator__base_score: None
#   • estimator__booster: None
#   • estimator__callbacks: None
#   • estimator__colsample_bylevel: None
#   • estimator__colsample_bynode: None
#   • estimator__colsample_bytree: 0.8
#   • estimator__device: cuda
#   • estimator__early_stopping_rounds: None
#   • estimator__enable_categorical: False
#   • estimator__eval_metric: None
#   • estimator__feature_types: None
#   • estimator__feature_weights: None
#   • estimator__gamma: 0.0
#   • estimator__grow_policy: None
#   • estimator__importance_type: None
#   • estimator__interaction_constraints: None
#   • estimator__learning_rate: 0.05
#   • estimator__max_bin: None
#   • estimator__max_cat_threshold: None
#   • estimator__max_cat_to_onehot: None
#   • estimator__max_delta_step: None
#   • estimator__max_depth: 6
#   • estimator__max_leaves: None
#   • estimator__min_child_weight: 1.0
#   • estimator__missing: nan
#   • estimator__monotone_constraints: None
#   • estimator__multi_strategy: None
#   • estimator__num_parallel_tree: None
#   • estimator__n_estimators: 2000
#   • estimator__n_jobs: -1
#   • estimator__objective: reg:squarederror
#   • estimator__random_state: 42
#   • estimator__reg_alpha: 0.0
#   • estimator__reg_lambda: 1.0
#   • estimator__sampling_method: None
#   • estimator__scale_pos_weight: None
#   • estimator__subsample: 0.8
#   • estimator__tree_method: hist
#   • estimator__validate_parameters: None
#   • estimator__verbosity: None
#   • gamma: 0.0
#   • learning_rate: 0.05
#   • max_depth: 6
#   • min_child_weight: 1.0
#   • n_estimators: 2000
#   • n_jobs: -1
#   • objective: reg:squarederror
#   • pooling: global
#   • random_state: 42
#   • reg_alpha: 0.0
#   • reg_lambda: 1.0
#   • subsample: 0.8
#   • targets: WVHT,APD
#   • transformers: [WindowSummarizer(lag_feature={'lag': [1, 24, 48, 72]}, truncate='bfill')]
#   • tree_method: hist
#   • window_length: None
# 📊 METRICS:
#   • MeanAbsolutePercentageError: 0.395455
#   • MeanSquaredPercentageError: 0.494877
# 🖼️ ARTIFACTS:
#   • plots
#
#
# 🔹 RUN 21 - SARIMA
# ----------------------------------------
# 📋 PARAMETERS:
#   • forecasters: [('SARIMA_WVHT', ARIMA(order=(1, 0, 1), seasonal_order=(0, 0, 0, 24)), ['WVHT']), ('SARIMA_APD', ARIMA(order=(1, 0, 1), seasonal_order=(0, 0, 0, 24)), ['APD'])]
#   • SARIMA_APD: ARIMA(order=(1, 0, 1), seasonal_order=(0, 0, 0, 24))
#   • SARIMA_APD__concentrate_scale: False
#   • SARIMA_APD__enforce_invertibility: True
#   • SARIMA_APD__enforce_stationarity: True
#   • SARIMA_APD__hamilton_representation: False
#   • SARIMA_APD__maxiter: 50
#   • SARIMA_APD__measurement_error: False
#   • SARIMA_APD__method: lbfgs
#   • SARIMA_APD__mle_regression: True
#   • SARIMA_APD__order: (1, 0, 1)
#   • SARIMA_APD__out_of_sample_size: 0
#   • SARIMA_APD__scoring: mse
#   • SARIMA_APD__scoring_args: None
#   • SARIMA_APD__seasonal_order: (0, 0, 0, 24)
#   • SARIMA_APD__simple_differencing: False
#   • SARIMA_APD__start_params: None
#   • SARIMA_APD__suppress_warnings: False
#   • SARIMA_APD__time_varying_regression: False
#   • SARIMA_APD__trend: None
#   • SARIMA_APD__with_intercept: True
#   • sarima_orders: {'WVHT': {'order': (1, 0, 1), 'seasonal_order': (0, 0, 0, 24)}, 'APD': {'order': (1, 0, 1), 'seasonal_order': (0, 0, 0, 24)}}
#   • SARIMA_WVHT: ARIMA(order=(1, 0, 1), seasonal_order=(0, 0, 0, 24))
#   • SARIMA_WVHT__concentrate_scale: False
#   • SARIMA_WVHT__enforce_invertibility: True
#   • SARIMA_WVHT__enforce_stationarity: True
#   • SARIMA_WVHT__hamilton_representation: False
#   • SARIMA_WVHT__maxiter: 50
#   • SARIMA_WVHT__measurement_error: False
#   • SARIMA_WVHT__method: lbfgs
#   • SARIMA_WVHT__mle_regression: True
#   • SARIMA_WVHT__order: (1, 0, 1)
#   • SARIMA_WVHT__out_of_sample_size: 0
#   • SARIMA_WVHT__scoring: mse
#   • SARIMA_WVHT__scoring_args: None
#   • SARIMA_WVHT__seasonal_order: (0, 0, 0, 24)
#   • SARIMA_WVHT__simple_differencing: False
#   • SARIMA_WVHT__start_params: None
#   • SARIMA_WVHT__suppress_warnings: False
#   • SARIMA_WVHT__time_varying_regression: False
#   • SARIMA_WVHT__trend: None
#   • SARIMA_WVHT__with_intercept: True
#   • targets: WVHT,APD
# 📊 METRICS:
#   • MeanAbsolutePercentageError: 0.366408
#   • MeanSquaredPercentageError: 0.491924
# 🖼️ ARTIFACTS:
#   • plots
#
#
# 🔹 RUN 22 - XGBoost
# ----------------------------------------
# 📋 PARAMETERS:
#   • colsample_bytree: 0.8
#   • device: cuda
#   • estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device='cuda', early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=0.0, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=1.0, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=2000,
#              n_jobs=-1, num_parallel_tree=None, ...)
#   • estimator__base_score: None
#   • estimator__booster: None
#   • estimator__callbacks: None
#   • estimator__colsample_bylevel: None
#   • estimator__colsample_bynode: None
#   • estimator__colsample_bytree: 0.8
#   • estimator__device: cuda
#   • estimator__early_stopping_rounds: None
#   • estimator__enable_categorical: False
#   • estimator__eval_metric: None
#   • estimator__feature_types: None
#   • estimator__feature_weights: None
#   • estimator__gamma: 0.0
#   • estimator__grow_policy: None
#   • estimator__importance_type: None
#   • estimator__interaction_constraints: None
#   • estimator__learning_rate: 0.05
#   • estimator__max_bin: None
#   • estimator__max_cat_threshold: None
#   • estimator__max_cat_to_onehot: None
#   • estimator__max_delta_step: None
#   • estimator__max_depth: 6
#   • estimator__max_leaves: None
#   • estimator__min_child_weight: 1.0
#   • estimator__missing: nan
#   • estimator__monotone_constraints: None
#   • estimator__multi_strategy: None
#   • estimator__num_parallel_tree: None
#   • estimator__n_estimators: 2000
#   • estimator__n_jobs: -1
#   • estimator__objective: reg:squarederror
#   • estimator__random_state: 42
#   • estimator__reg_alpha: 0.0
#   • estimator__reg_lambda: 1.0
#   • estimator__sampling_method: None
#   • estimator__scale_pos_weight: None
#   • estimator__subsample: 0.8
#   • estimator__tree_method: hist
#   • estimator__validate_parameters: None
#   • estimator__verbosity: None
#   • gamma: 0.0
#   • learning_rate: 0.05
#   • max_depth: 6
#   • min_child_weight: 1.0
#   • n_estimators: 2000
#   • n_jobs: -1
#   • objective: reg:squarederror
#   • pooling: global
#   • random_state: 42
#   • reg_alpha: 0.0
#   • reg_lambda: 1.0
#   • subsample: 0.8
#   • targets: WVHT,APD
#   • transformers: [WindowSummarizer(lag_feature={'lag': [1, 24, 48, 72]}, truncate='bfill')]
#   • tree_method: hist
#   • window_length: None
# 📊 METRICS:
#   • MeanAbsolutePercentageError: 0.929118
#   • MeanSquaredPercentageError: 1.286189
# 🖼️ ARTIFACTS:
#   • plots
#
#
# 🔹 RUN 23 - SARIMA
# ----------------------------------------
# 📋 PARAMETERS:
#   • forecasters: [('SARIMA_WVHT', ARIMA(order=(1, 0, 1), seasonal_order=(0, 0, 0, 24)), ['WVHT']), ('SARIMA_APD', ARIMA(order=(1, 0, 1), seasonal_order=(0, 0, 0, 24)), ['APD'])]
#   • SARIMA_APD: ARIMA(order=(1, 0, 1), seasonal_order=(0, 0, 0, 24))
#   • SARIMA_APD__concentrate_scale: False
#   • SARIMA_APD__enforce_invertibility: True
#   • SARIMA_APD__enforce_stationarity: True
#   • SARIMA_APD__hamilton_representation: False
#   • SARIMA_APD__maxiter: 50
#   • SARIMA_APD__measurement_error: False
#   • SARIMA_APD__method: lbfgs
#   • SARIMA_APD__mle_regression: True
#   • SARIMA_APD__order: (1, 0, 1)
#   • SARIMA_APD__out_of_sample_size: 0
#   • SARIMA_APD__scoring: mse
#   • SARIMA_APD__scoring_args: None
#   • SARIMA_APD__seasonal_order: (0, 0, 0, 24)
#   • SARIMA_APD__simple_differencing: False
#   • SARIMA_APD__start_params: None
#   • SARIMA_APD__suppress_warnings: False
#   • SARIMA_APD__time_varying_regression: False
#   • SARIMA_APD__trend: None
#   • SARIMA_APD__with_intercept: True
#   • sarima_orders: {'WVHT': {'order': (1, 0, 1), 'seasonal_order': (0, 0, 0, 24)}, 'APD': {'order': (1, 0, 1), 'seasonal_order': (0, 0, 0, 24)}}
#   • SARIMA_WVHT: ARIMA(order=(1, 0, 1), seasonal_order=(0, 0, 0, 24))
#   • SARIMA_WVHT__concentrate_scale: False
#   • SARIMA_WVHT__enforce_invertibility: True
#   • SARIMA_WVHT__enforce_stationarity: True
#   • SARIMA_WVHT__hamilton_representation: False
#   • SARIMA_WVHT__maxiter: 50
#   • SARIMA_WVHT__measurement_error: False
#   • SARIMA_WVHT__method: lbfgs
#   • SARIMA_WVHT__mle_regression: True
#   • SARIMA_WVHT__order: (1, 0, 1)
#   • SARIMA_WVHT__out_of_sample_size: 0
#   • SARIMA_WVHT__scoring: mse
#   • SARIMA_WVHT__scoring_args: None
#   • SARIMA_WVHT__seasonal_order: (0, 0, 0, 24)
#   • SARIMA_WVHT__simple_differencing: False
#   • SARIMA_WVHT__start_params: None
#   • SARIMA_WVHT__suppress_warnings: False
#   • SARIMA_WVHT__time_varying_regression: False
#   • SARIMA_WVHT__trend: None
#   • SARIMA_WVHT__with_intercept: True
#   • targets: WVHT,APD
# 📊 METRICS:
#   • MeanAbsolutePercentageError: 0.551020
#   • MeanSquaredPercentageError: 0.792764
# 🖼️ ARTIFACTS:
#   • plots
#
#
# 🔹 RUN 24 - XGBoost
# ----------------------------------------
# 📋 PARAMETERS:
#   • colsample_bytree: 0.8
#   • device: cuda
#   • estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device='cuda', early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=0.0, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.01, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=12,
#              max_leaves=None, min_child_weight=1.0, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=2000,
#              n_jobs=-1, num_parallel_tree=None, ...)
#   • estimator__base_score: None
#   • estimator__booster: None
#   • estimator__callbacks: None
#   • estimator__colsample_bylevel: None
#   • estimator__colsample_bynode: None
#   • estimator__colsample_bytree: 0.8
#   • estimator__device: cuda
#   • estimator__early_stopping_rounds: None
#   • estimator__enable_categorical: False
#   • estimator__eval_metric: None
#   • estimator__feature_types: None
#   • estimator__feature_weights: None
#   • estimator__gamma: 0.0
# ...
#   • estimator__random_state: 42
#   • estimator__reg_alpha: None
#   • estimator__reg_lambda: None
#   • estimator__sampling_method: None
#   • estimator__scale_pos_weight: None
#   • estimator__subsample: 0.8
#   • estimator__tree_method: hist
#   • estimator__validate_parameters: None
#   • estimator__verbosity: None
#   • learning_rate: 0.01
#   • max_depth: 8
#   • n_estimators: 800
#   • n_jobs: -1
#   • objective: reg:squarederror
#   • pooling: global
#   • random_state: 42
#   • subsample: 0.8
#   • targets: WVHT,APD
#   • transformers: [WindowSummarizer(lag_feature={'lag': [1, 2, 3, 4, 24, 48],
#                               'mean': [[1, 24], [24, 48]]},
#                  truncate='bfill')]
#   • tree_method: hist
#   • window_length: None
# 📊 METRICS:
#   • MeanAbsolutePercentageError: 0.793376
#   • MeanSquaredPercentageError: 1.143800
# 🖼️ ARTIFACTS:
#   • plots
#
#
# 🔹 RUN 55 - XGBoost
# ----------------------------------------
# 📋 PARAMETERS:
#   • block_size: 72
#   • colsample_bytree: 0.8
#   • estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.01, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=8,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=800,
#              n_jobs=-1, num_parallel_tree=None, ...)
#   • estimator__base_score: None
#   • estimator__booster: None
#   • estimator__callbacks: None
#   • estimator__colsample_bylevel: None
#   • estimator__colsample_bynode: None
#   • estimator__colsample_bytree: 0.8
#   • estimator__device: None
#   • estimator__early_stopping_rounds: None
#   • estimator__enable_categorical: False
#   • estimator__eval_metric: None
#   • estimator__feature_types: None
#   • estimator__feature_weights: None
#   • estimator__gamma: None
#   • estimator__grow_policy: None
#   • estimator__importance_type: None
#   • estimator__interaction_constraints: None
#   • estimator__learning_rate: 0.01
#   • estimator__max_bin: None
#   • estimator__max_cat_threshold: None
#   • estimator__max_cat_to_onehot: None
#   • estimator__max_delta_step: None
#   • estimator__max_depth: 8
#   • estimator__max_leaves: None
#   • estimator__min_child_weight: None
#   • estimator__missing: nan
#   • estimator__monotone_constraints: None
#   • estimator__multi_strategy: None
#   • estimator__num_parallel_tree: None
#   • estimator__n_estimators: 800
#   • estimator__n_jobs: -1
#   • estimator__objective: reg:squarederror
#   • estimator__random_state: 42
#   • estimator__reg_alpha: None
#   • estimator__reg_lambda: None
#   • estimator__sampling_method: None
#   • estimator__scale_pos_weight: None
#   • estimator__subsample: 0.8
#   • estimator__tree_method: hist
#   • estimator__validate_parameters: None
#   • estimator__verbosity: None
#   • learning_rate: 0.01
#   • max_depth: 8
#   • n_blocks: 3
#   • n_estimators: 800
#   • n_jobs: -1
#   • objective: reg:squarederror
#   • pooling: global
#   • random_state: 42
#   • subsample: 0.8
#   • targets: WVHT,APD
#   • transformers: [WindowSummarizer(lag_feature={'lag': [1, 2, 3, 4, 24, 48],
#                               'mean': [[1, 24], [24, 48]]},
#                  truncate='bfill')]
#   • tree_method: hist
#   • window_length: None
# 📊 METRICS:
#   • avg_MeanAbsolutePercentageError: 0.473511
#   • avg_MeanSquaredPercentageError: 0.612295
#   • block_1_MeanAbsolutePercentageError: 0.423424
#   • block_1_MeanSquaredPercentageError: 0.601598
#   • block_2_MeanAbsolutePercentageError: 0.426631
#   • block_2_MeanSquaredPercentageError: 0.550668
#   • block_3_MeanAbsolutePercentageError: 0.570478
#   • block_3_MeanSquaredPercentageError: 0.684619
#   • std_MeanAbsolutePercentageError: 0.068579
#   • std_MeanSquaredPercentageError: 0.055206
# 🖼️ ARTIFACTS:
#   • plots
#
#
# 🔹 RUN 56 - XGBoost
# ----------------------------------------
# 📋 PARAMETERS:
#   • block_size: 72
#   • colsample_bytree: 0.8
#   • estimator: XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.01, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=8,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=800,
#              n_jobs=-1, num_parallel_tree=None, ...)
#   • estimator__base_score: None
#   • estimator__booster: None
#   • estimator__callbacks: None
#   • estimator__colsample_bylevel: None
#   • estimator__colsample_bynode: None
#   • estimator__colsample_bytree: 0.8
#   • estimator__device: None
#   • estimator__early_stopping_rounds: None
#   • estimator__enable_categorical: False
#   • estimator__eval_metric: None
#   • estimator__feature_types: None
#   • estimator__feature_weights: None
#   • estimator__gamma: None
#   • estimator__grow_policy: None
#   • estimator__importance_type: None
#   • estimator__interaction_constraints: None
#   • estimator__learning_rate: 0.01
#   • estimator__max_bin: None
#   • estimator__max_cat_threshold: None
#   • estimator__max_cat_to_onehot: None
#   • estimator__max_delta_step: None
#   • estimator__max_depth: 8
#   • estimator__max_leaves: None
#   • estimator__min_child_weight: None
#   • estimator__missing: nan
#   • estimator__monotone_constraints: None
#   • estimator__multi_strategy: None
#   • estimator__num_parallel_tree: None
#   • estimator__n_estimators: 800
#   • estimator__n_jobs: -1
#   • estimator__objective: reg:squarederror
#   • estimator__random_state: 42
#   • estimator__reg_alpha: None
#   • estimator__reg_lambda: None
#   • estimator__sampling_method: None
#   • estimator__scale_pos_weight: None
#   • estimator__subsample: 0.8
#   • estimator__tree_method: hist
#   • estimator__validate_parameters: None
#   • estimator__verbosity: None
#   • learning_rate: 0.01
#   • max_depth: 8
#   • n_blocks: 3
#   • n_estimators: 800
#   • n_jobs: -1
#   • objective: reg:squarederror
#   • pooling: global
#   • random_state: 42
#   • subsample: 0.8
#   • targets: WVHT,APD
#   • transformers: [WindowSummarizer(lag_feature={'lag': [1, 2, 3, 4, 24, 48],
#                               'mean': [[1, 24], [24, 48]]},
#                  truncate='bfill')]
#   • tree_method: hist
#   • window_length: None
# 📊 METRICS:
#   • avg_MeanAbsolutePercentageError: 0.473511
#   • avg_MeanSquaredPercentageError: 0.612295
#   • block_1_MeanAbsolutePercentageError: 0.423424
#   • block_1_MeanSquaredPercentageError: 0.601598
#   • block_2_MeanAbsolutePercentageError: 0.426631
#   • block_2_MeanSquaredPercentageError: 0.550668
#   • block_3_MeanAbsolutePercentageError: 0.570478
#   • block_3_MeanSquaredPercentageError: 0.684619
#   • std_MeanAbsolutePercentageError: 0.068579
#   • std_MeanSquaredPercentageError: 0.055206
# 🖼️ ARTIFACTS:
#   • plots
#
#
# 🔹 RUN 57 - Naive
# ----------------------------------------
# 📋 PARAMETERS:
#   • block_size: 72
#   • forecasters: [('naive_last_WVHT', NaiveForecaster(), ['WVHT']), ('naive_mean_APD', NaiveForecaster(strategy='mean'), ['APD'])]
#   • naive_last_WVHT: NaiveForecaster()
#   • naive_last_WVHT__sp: 1
#   • naive_last_WVHT__strategy: last
#   • naive_last_WVHT__window_length: None
#   • naive_mean_APD: NaiveForecaster(strategy='mean')
#   • naive_mean_APD__sp: 1
#   • naive_mean_APD__strategy: mean
#   • naive_mean_APD__window_length: None
#   • n_blocks: 3
#   • strategies: {'WVHT': 'last', 'APD': 'mean'}
#   • targets: WVHT,APD
# 📊 METRICS:
#   • avg_MeanAbsolutePercentageError: 0.673963
#   • avg_MeanSquaredPercentageError: 0.843051
#   • block_1_MeanAbsolutePercentageError: 0.349492
#   • block_1_MeanSquaredPercentageError: 0.494596
#   • block_2_MeanAbsolutePercentageError: 0.582110
#   • block_2_MeanSquaredPercentageError: 0.778764
#   • block_3_MeanAbsolutePercentageError: 1.090288
#   • block_3_MeanSquaredPercentageError: 1.255792
#   • std_MeanAbsolutePercentageError: 0.309325
#   • std_MeanSquaredPercentageError: 0.314064
# 🖼️ ARTIFACTS:
#   • plots
#
#
# 🔹 RUN 58 - SARIMA
# ----------------------------------------
# 📋 PARAMETERS:
#   • block_size: 72
#   • forecasters: [('SARIMA_WVHT', ARIMA(order=(1, 0, 1), seasonal_order=(0, 0, 0, 24)), ['WVHT']), ('SARIMA_APD', ARIMA(order=(1, 0, 1), seasonal_order=(0, 0, 0, 24)), ['APD'])]
#   • n_blocks: 3
#   • SARIMA_APD: ARIMA(order=(1, 0, 1), seasonal_order=(0, 0, 0, 24))
#   • SARIMA_APD__concentrate_scale: False
#   • SARIMA_APD__enforce_invertibility: True
#   • SARIMA_APD__enforce_stationarity: True
#   • SARIMA_APD__hamilton_representation: False
#   • SARIMA_APD__maxiter: 50
#   • SARIMA_APD__measurement_error: False
#   • SARIMA_APD__method: lbfgs
#   • SARIMA_APD__mle_regression: True
#   • SARIMA_APD__order: (1, 0, 1)
#   • SARIMA_APD__out_of_sample_size: 0
#   • SARIMA_APD__scoring: mse
#   • SARIMA_APD__scoring_args: None
#   • SARIMA_APD__seasonal_order: (0, 0, 0, 24)
#   • SARIMA_APD__simple_differencing: False
#   • SARIMA_APD__start_params: None
#   • SARIMA_APD__suppress_warnings: False
#   • SARIMA_APD__time_varying_regression: False
#   • SARIMA_APD__trend: None
#   • SARIMA_APD__with_intercept: True
#   • sarima_orders: see_code
#   • SARIMA_WVHT: ARIMA(order=(1, 0, 1), seasonal_order=(0, 0, 0, 24))
#   • SARIMA_WVHT__concentrate_scale: False
#   • SARIMA_WVHT__enforce_invertibility: True
#   • SARIMA_WVHT__enforce_stationarity: True
#   • SARIMA_WVHT__hamilton_representation: False
#   • SARIMA_WVHT__maxiter: 50
#   • SARIMA_WVHT__measurement_error: False
#   • SARIMA_WVHT__method: lbfgs
#   • SARIMA_WVHT__mle_regression: True
#   • SARIMA_WVHT__order: (1, 0, 1)
#   • SARIMA_WVHT__out_of_sample_size: 0
#   • SARIMA_WVHT__scoring: mse
#   • SARIMA_WVHT__scoring_args: None
#   • SARIMA_WVHT__seasonal_order: (0, 0, 0, 24)
#   • SARIMA_WVHT__simple_differencing: False
#   • SARIMA_WVHT__start_params: None
#   • SARIMA_WVHT__suppress_warnings: False
#   • SARIMA_WVHT__time_varying_regression: False
#   • SARIMA_WVHT__trend: None
#   • SARIMA_WVHT__with_intercept: True
#   • targets: WVHT,APD
# 📊 METRICS:
#   • avg_MeanAbsolutePercentageError: 0.504175
#   • avg_MeanSquaredPercentageError: 0.634932
#   • block_1_MeanAbsolutePercentageError: 0.327580
#   • block_1_MeanSquaredPercentageError: 0.429270
#   • block_2_MeanAbsolutePercentageError: 0.401207
#   • block_2_MeanSquaredPercentageError: 0.561175
#   • block_3_MeanAbsolutePercentageError: 0.783738
#   • block_3_MeanSquaredPercentageError: 0.914351
#   • std_MeanAbsolutePercentageError: 0.199953
#   • std_MeanSquaredPercentageError: 0.204786
# 🖼️ ARTIFACTS:
#   • plots
#
# ============================================================
# MLFLOW EXPERIMENT: Oceanwave_DeepAR_Training
# ============================================================
#
# 🔹 RUN 1 - DeepAR
# ----------------------------------------
# 📋 PARAMETERS:
#   • batch_size: 64
#   • embedding_dim: 32
#   • gradient_clip_val: 0.1
#   • horizon: 72
#   • learning_rate: 0.001
#   • lstm_dropout: 0.2
#   • lstm_hidden_dim: 128
#   • lstm_layers: 3
#   • max_epochs: 2500
#   • num_class: 12
#   • optimizer: adamw
#   • targets: WVHT,APD
#   • window: 504
# 📊 METRICS:
#   • No metrics recorded
# 🖼️ ARTIFACTS:
#   • model
#
#
# 🔹 RUN 2 - DeepAR
# ----------------------------------------
# 📋 PARAMETERS:
#   • batch_size: 64
#   • embedding_dim: 32
#   • gradient_clip_val: 0.1
#   • horizon: 72
#   • learning_rate: 0.001
#   • lstm_dropout: 0.2
#   • lstm_hidden_dim: 128
#   • lstm_layers: 3
#   • max_epochs: 2500
#   • num_class: 12
#   • optimizer: adamw
#   • targets: WVHT,APD
#   • window: 504
# 📊 METRICS:
#   • dummy_MAE: 0.249816
#   • dummy_MAPE: 0.339463
#   • dummy_RMSE: 0.480286
#   • dummy_SMAPE: 0.392798
# 🖼️ ARTIFACTS:
#   • model
#
#
# 🔹 RUN 3 - DeepAR
# ----------------------------------------
# 📋 PARAMETERS:
#   • batch_size: 64
#   • horizon: 72
#   • learning_rate: 0.001
#   • lstm_dropout: 0.1
#   • lstm_hidden_dim: 64
#   • lstm_layers: 3
#   • max_epochs: 2500
#   • optimizer: adamw
#   • targets: WVHT,APD
#   • window: 504
# 📊 METRICS:
#   • No metrics recorded
# 🖼️ ARTIFACTS:
#   • model
#
#
# 🔹 RUN 4 - DeepAR
# ----------------------------------------
# 📋 PARAMETERS:
#   • batch_size: 64
#   • horizon: 72
#   • learning_rate: 0.001
#   • lstm_dropout: 0.2
#   • lstm_hidden_dim: 64
#   • lstm_layers: 3
#   • max_epochs: 2500
#   • optimizer: adamw
#   • targets: WVHT,APD
#   • window: 504
# 📊 METRICS:
#   • dummy_MAE: 0.249816
#   • dummy_MAPE: 0.339463
#   • dummy_RMSE: 0.480286
#   • dummy_SMAPE: 0.392798
# 🖼️ ARTIFACTS:
#   • model
#
#
# 🔹 RUN 5 - DeepAR
# ----------------------------------------
# 📋 PARAMETERS:
#   • batch_size: 64
#   • horizon: 72
#   • learning_rate: 0.001
#   • lstm_dropout: 0.1
#   • lstm_hidden_dim: 128
#   • lstm_layers: 2
#   • max_epochs: 2500
#   • optimizer: adamw
#   • targets: WVHT,APD
#   • window: 504
# 📊 METRICS:
#   • dummy_MAE: 0.249816
#   • dummy_MAPE: 0.339463
#   • dummy_RMSE: 0.480286
#   • dummy_SMAPE: 0.392798
# 🖼️ ARTIFACTS:
#   • model
#
#
# 🔹 RUN 6 - DeepAR
# ----------------------------------------
# 📋 PARAMETERS:
#   • batch_size: 64
#   • horizon: 72
#   • learning_rate: 0.001
#   • lstm_dropout: 0.2
#   • lstm_hidden_dim: 128
#   • lstm_layers: 2
#   • max_epochs: 2500
#   • optimizer: adamw
#   • targets: WVHT,APD
#   • window: 504
# 📊 METRICS:
#   • dummy_MAE: 0.162407
#   • dummy_MAPE: 0.446470
#   • dummy_RMSE: 0.162398
#   • dummy_SMAPE: 0.123233
# 🖼️ ARTIFACTS:
#   • model
#
#
# 🔹 RUN 7 - DeepAR
# ----------------------------------------
# 📋 PARAMETERS:
#   • batch_size: 64
#   • horizon: 72
#   • learning_rate: 0.001
#   • lstm_dropout: 0.1
#   • lstm_hidden_dim: 128
#   • lstm_layers: 3
#   • max_epochs: 2500
#   • optimizer: adamw
#   • targets: WVHT,APD
#   • window: 504
# 📊 METRICS:
#   • dummy_MAE: 0.340446
#   • dummy_MAPE: 0.487964
#   • dummy_RMSE: 0.383229
#   • dummy_SMAPE: 0.108234
# 🖼️ ARTIFACTS:
#   • model
#
#
# 🔹 RUN 8 - DeepAR
# ----------------------------------------
# 📋 PARAMETERS:
#   • batch_size: 64
#   • horizon: 72
#   • learning_rate: 0.001
#   • lstm_dropout: 0.2
#   • lstm_hidden_dim: 128
#   • lstm_layers: 3
#   • max_epochs: 2500
#   • optimizer: adamw
#   • targets: WVHT,APD
#   • window: 504
# 📊 METRICS:
#   • dummy_MAE: 0.432977
#   • dummy_MAPE: 0.173362
#   • dummy_RMSE: 0.184936
#   • dummy_SMAPE: 0.172730
# 🖼️ ARTIFACTS:
#   • model
#
#
# 🔹 RUN 9 - DeepAR
# ----------------------------------------
# 📋 PARAMETERS:
#   • batch_size: 64
#   • horizon: 72
#   • learning_rate: 0.0001
#   • lstm_dropout: 0.1
#   • lstm_hidden_dim: 256
#   • lstm_layers: 2
#   • max_epochs: 2500
#   • optimizer: adamw
#   • targets: WVHT,APD
#   • window: 504
# 📊 METRICS:
#   • dummy_MAE: 0.221697
#   • dummy_MAPE: 0.216492
#   • dummy_RMSE: 0.309903
#   • dummy_SMAPE: 0.272778
# 🖼️ ARTIFACTS:
#   • model
#
#
# 🔹 RUN 10 - DeepAR
# ----------------------------------------
# 📋 PARAMETERS:
#   • batch_size: 64
#   • horizon: 72
#   • learning_rate: 0.0001
#   • lstm_dropout: 0.2
#   • lstm_hidden_dim: 256
#   • lstm_layers: 2
#   • max_epochs: 2500
#   • optimizer: adamw
#   • targets: WVHT,APD
#   • window: 504
# 📊 METRICS:
#   • dummy_MAE: 0.344741
#   • dummy_MAPE: 0.246545
#   • dummy_RMSE: 0.155798
#   • dummy_SMAPE: 0.216858
# 🖼️ ARTIFACTS:
#   • model
#
#
# 🔹 RUN 11 - DeepAR
# ----------------------------------------
# 📋 PARAMETERS:
#   • batch_size: 64
#   • horizon: 72
#   • learning_rate: 0.0001
#   • lstm_dropout: 0.1
#   • lstm_hidden_dim: 256
#   • lstm_layers: 3
#   • max_epochs: 2500
#   • optimizer: adamw
#   • targets: WVHT,APD
#   • window: 504
# 📊 METRICS:
#   • dummy_MAE: 0.282428
#   • dummy_MAPE: 0.305694
#   • dummy_RMSE: 0.414070
#   • dummy_SMAPE: 0.179870
# 🖼️ ARTIFACTS:
#   • model
#
#
# 🔹 RUN 12 - DeepAR
# ----------------------------------------
# 📋 PARAMETERS:
#   • batch_size: 64
#   • horizon: 72
#   • learning_rate: 0.0001
#   • lstm_dropout: 0.2
#   • lstm_hidden_dim: 256
#   • lstm_layers: 3
#   • max_epochs: 2500
#   • optimizer: adamw
#   • targets: WVHT,APD
#   • window: 504
# 📊 METRICS:
#   • dummy_MAE: 0.336966
#   • dummy_MAPE: 0.168210
#   • dummy_RMSE: 0.118580
#   • dummy_SMAPE: 0.343018
# 🖼️ ARTIFACTS:
#   • model
